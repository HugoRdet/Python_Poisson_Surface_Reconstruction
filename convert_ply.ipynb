# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objects as go
import bloscpack as bp

from utils import*

# %%
def get_file_ply(name):
    f = open(name, "r")
    content=f.read()
    lines=content.split("\n")
    print(lines[:15])
    nb_vert=int(lines[7].split(" ")[-1])
    nb_faces=int(lines[8].split(" ")[-1])

    vert=dict()
    cpt_vert=1
    cpt_norm=1
    norm=dict()
    res=torch.empty(nb_vert,6)
    cpt_res=0
    L_fait=[]

    for l in lines:
        
        if len(l)<1 or (l[0]!="v" and l[:2]!="vn" and l[0]!="f"):
            continue
        else:
            if l[:2]=="vn":
                l=l.split(" ")
                x=float(l[1])
                y=float(l[2])
                z=float(l[3])
                norm[cpt_vert]=(x,y,z)
                cpt_norm+=1
                continue
            if l[:2]=="v ":
                l=l.split(" ")
                x=float(l[1])
                y=float(l[2])
                z=float(l[3])
                vert[cpt_vert]=(x,y,z)
                cpt_vert+=1
                continue
            if l[:2]=="f ":
                l=l.split(" ")
                l=l[1:]
                for elem in l:
                    if len(elem)<=1:
                        continue
                    else:
                        elem=elem.split("/")
                        if int(elem[0]) in L_fait:
                            continue
                        L_fait.append(int(elem[0]))
                        xv,yv,zv=vert[int(elem[0])]
                        xn,yn,zn=norm[int(elem[-1])]

                        res[cpt_res,0]=xv
                        res[cpt_res,1]=yv
                        res[cpt_res,2]=zv
                        res[cpt_res,3]=xn
                        res[cpt_res,4]=yn
                        res[cpt_res,5]=zn
                        cpt_res+=1
                        

                
                    
                
                continue
    return res

# %%
tmp=get_file_ply("./data/suzanne.obj")
# Out:
# ['####', '#', '# OBJ File Generated by Meshlab', '#', '####', '# Object suzanne.obj', '#', '# Vertices: 507', '# Faces: 500', '#', '####', 'vn 0.744549 -0.641131 0.186007', 'v -2.056562 1.415748 4.869517', 'vn -0.744549 -0.641135 0.185990', 'v -2.931562 1.415748 4.869517']

# %%
print(tmp)
# Out:
# tensor([[-2.0566,  1.4157,  4.8695,  0.7445, -0.6411,  0.1860],
#         [-1.9941,  1.3454,  4.7914,  0.5936, -0.4956,  0.6341],
#         [-1.9316,  1.4939,  4.7758,  0.7832, -0.0218,  0.6214],
#         ...,
#         [-3.5175,  1.6892,  3.6195,  0.4704,  0.4673, -0.7486],
#         [-1.6347,  1.6345,  3.7211, -0.4889,  0.5157, -0.7036],
#         [-3.3534,  1.6345,  3.7211,  0.4889,  0.5157, -0.7036]])
